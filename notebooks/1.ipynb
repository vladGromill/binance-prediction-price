# %%
import pandas as pd
import numpy as np
import os
import sys
# ensure project src/ is importable from the notebook
sys.path.append(os.path.join(os.getcwd(), "src"))
# import from the package wrapper — this will try to load modules
from data_collector import ParquetDataLoader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       4 import sys
#       5 sys.path.append(os.path.join(os.getcwd(), "src"))
# ----> 6 from data_collector import ParquetDataLoader
#
# ModuleNotFoundError: No module named 'data_collector'

# %%
df = pd.read_parquet("binance_orderbook/2026-01-11.parquet")

# %%
df
# Out:
#                       datetime  bid_price_1  bid_price_2  bid_price_3  \
# 0      2026-01-11 00:00:00.146      3083.34      3083.32      3083.30
# 1      2026-01-11 00:00:00.246      3083.34      3083.32      3083.30
# 2      2026-01-11 00:00:00.346      3083.34      3083.32      3083.30
# 3      2026-01-11 00:00:00.446      3083.34      3083.32      3083.30
# 4      2026-01-11 00:00:00.546      3083.34      3083.32      3083.30
# ...                        ...          ...          ...          ...
# 568105 2026-01-11 23:59:59.543      3120.07      3119.95      3119.90
# 568106 2026-01-11 23:59:59.643      3119.85      3119.80      3119.75
# 568107 2026-01-11 23:59:59.743      3119.85      3119.80      3119.75
# 568108 2026-01-11 23:59:59.843      3119.85      3119.80      3119.75
# 568109 2026-01-11 23:59:59.943      3119.63      3119.60      3119.55
#
#         bid_price_4  bid_price_5  bid_price_6  bid_price_7  bid_price_8  \
# ...

# %%
trades = pd.read_parquet("binance_trades/binance_trades.paruqet")

# %%
trades.datetime.min()
# Out:
# Timestamp('2026-01-10 00:00:02.806000')

# %%
trades.datetime.max()
# Out:
# Timestamp('2026-01-15 23:59:56.959000')

# %%
trades.shape
# Out:
# (3355537, 6)
