# %%
import pandas as pd
import numpy as np
import os, sys
from pathlib import Path

p = Path(os.getcwd())
for _ in range(6):
    candidate = p / 'src'
    if candidate.exists():
        sys.path.insert(0, str(candidate))
        break
    p = p.parent
print('using src at', sys.path[0])

try:
    from data_collector.data_loader import ParquetDataLoader, DataLoadConfig
except Exception as e:
    from data_collector import ParquetDataLoader, DataLoadConfig  # type: ignore
# Out:
# using src at /Users/vladislavshchekotikhin/Desktop/работа/binance prediction price/src

# %%
config = DataLoadConfig(
    path_to_orderbook="../binance_orderbook",
    path_to_trades="../binance_trades",
    dates_orderbook=[f"2026-01-1{i}" for i in range(1, 6)],
    data_trades="binance_trades.parquet",
    load_orderbook=True,
    load_trades=False,
    cols_orderbook=None,
    cols_trades= None,
)

# %%
data_loader = ParquetDataLoader(config)
data = data_loader.load_data()

# %%
data
# Out:
#                        datetime  bid_price_1  bid_price_2  bid_price_3  \
# 0       2026-01-11 00:00:00.146      3083.34      3083.32      3083.30
# 1       2026-01-11 00:00:00.246      3083.34      3083.32      3083.30
# 2       2026-01-11 00:00:00.346      3083.34      3083.32      3083.30
# 3       2026-01-11 00:00:00.446      3083.34      3083.32      3083.30
# 4       2026-01-11 00:00:00.546      3083.34      3083.32      3083.30
# ...                         ...          ...          ...          ...
# 3495593 2026-01-15 23:59:59.242      3318.70      3318.66      3318.65
# 3495594 2026-01-15 23:59:59.441      3318.70      3318.66      3318.65
# 3495595 2026-01-15 23:59:59.541      3318.70      3318.66      3318.65
# 3495596 2026-01-15 23:59:59.641      3318.70      3318.66      3318.65
# 3495597 2026-01-15 23:59:59.841      3318.70      3318.66      3318.65
#
#          bid_price_4  bid_price_5  bid_price_6  bid_price_7  bid_price_8  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3495598 entries, 0 to 3495597
# Data columns (total 81 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   datetime      datetime64[ns]
#  1   bid_price_1   float64
#  2   bid_price_2   float64
#  3   bid_price_3   float64
#  4   bid_price_4   float64
#  5   bid_price_5   float64
#  6   bid_price_6   float64
#  7   bid_price_7   float64
#  8   bid_price_8   float64
#  9   bid_price_9   float64
#  10  bid_price_10  float64
#  11  bid_price_11  float64
#  12  bid_price_12  float64
#  13  bid_price_13  float64
#  14  bid_price_14  float64
#  15  bid_price_15  float64
#  16  bid_price_16  float64
#  17  bid_price_17  float64
#  18  bid_price_18  float64
#  19  bid_price_19  float64
#  20  bid_price_20  float64
#  21  ask_price_1   float64
#  22  ask_price_2   float64
#  23  ask_price_3   float64
#  24  ask_price_4   float64
#  25  ask_price_5   float64
#  26  ask_price_6   float64
#  27  ask_price_7   float64
# ...
